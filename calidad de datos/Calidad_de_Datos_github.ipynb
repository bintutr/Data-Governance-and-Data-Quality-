# %% [markdown]
# # Modulo de Gobierno de los Datos

# %% [markdown]
# 1. Carga de Archivos:

# %%
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv")
print(archivo)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# 2. Aplicar la funcion **Isnull** y **notnull()** al Dataset. Agregar una interpretacion personal de los resultados.

# %%
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv")
null_values = archivo.isnull()
print(null_values)
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %% [markdown]
# Con este código se muestran los valores con nulos con término TRUE

# %%
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv")
not_null_values = archivo.notnull()
print(not_null_values)
# Out:
#          id  name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      True  True     True       True                 True           True
# 1      True  True     True       True                 True           True
# 2      True  True     True       True                 True           True
# 3      True  True     True       True                 True           True
# 4      True  True     True       True                 True           True
# ...     ...   ...      ...        ...                  ...            ...
# 48890  True  True     True       True                 True           True
# 48891  True  True     True       True                 True           True
# 48892  True  True     True       True                 True           True
# 48893  True  True     True       True                 True           True
# 48894  True  True     True       True                 True           True
#
#        latitude  longitude  room_type  price  minimum_nights  \
# ...

# %% [markdown]
# Con esta esta función podemos observar que los valores que no son nulos se muestran con el término TRUE y los que son nulos con el término FALSE.

# %%
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv")
for column in archivo.columns:
    null_count = archivo[column].isnull().sum()
    not_null_count = archivo[column].notnull().sum()
    print(f"Columna '{column}': {null_count} valaores nulos, {not_null_count} valores no nulos")
# Out:
# Columna 'id': 0 valaores nulos, 48895 valores no nulos
# Columna 'name': 16 valaores nulos, 48879 valores no nulos
# Columna 'host_id': 0 valaores nulos, 48895 valores no nulos
# Columna 'host_name': 21 valaores nulos, 48874 valores no nulos
# Columna 'neighbourhood_group': 0 valaores nulos, 48895 valores no nulos
# Columna 'neighbourhood': 0 valaores nulos, 48895 valores no nulos
# Columna 'latitude': 0 valaores nulos, 48895 valores no nulos
# Columna 'longitude': 0 valaores nulos, 48895 valores no nulos
# Columna 'room_type': 0 valaores nulos, 48895 valores no nulos
# Columna 'price': 0 valaores nulos, 48895 valores no nulos
# Columna 'minimum_nights': 0 valaores nulos, 48895 valores no nulos
# Columna 'number_of_reviews': 0 valaores nulos, 48895 valores no nulos
# Columna 'last_review': 10052 valaores nulos, 38843 valores no nulos
# Columna 'reviews_per_month': 10052 valaores nulos, 38843 valores no nulos
# ...

# %% [markdown]
# 3. Ejecutar la funcion **info()**. Comentar brevemente los hallazgos identificados.

# %%
print(archivo.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# Se puede observar un DataFrame compuesto por 16 columnas y 48895 filas. Así mismo, podemos ver por cada una de las columnas la totalidad de datos que no son nulos y los tipos de datos que contienen. Por último, vemos la cantidad que está usdando rl DataFrame en el sistema, que en este caso es de 6 MB aproximadamente.

# %% [markdown]
# 4. Analizar los tipos de datos del dataset

# %%
tipos_de_datos = archivo.dtypes
print(tipos_de_datos)
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
print(archivo.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# 5. Indagar sobre las dimensiones de nuestro dataset

# %%
print(archivo.shape)
# Out:
# (48895, 16)

# %%
print(archivo.count())
# Out:
# id                                48895
# name                              48879
# host_id                           48895
# host_name                         48874
# neighbourhood_group               48895
# neighbourhood                     48895
# latitude                          48895
# longitude                         48895
# room_type                         48895
# price                             48895
# minimum_nights                    48895
# number_of_reviews                 48895
# last_review                       38843
# reviews_per_month                 38843
# calculated_host_listings_count    48895
# availability_365                  48895
# dtype: int64

# %% [markdown]
# 6. Eliminar los valores nulos con la funcion dropna()

# %%
nuevo_archivo = archivo.dropna()
print(nuevo_archivo)
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
archivo.dropna(inplace = True)
print(archivo)
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %% [markdown]
# 7. Como hemos observamos anteriormente, se pierden muchos registros. Razon por la cual, se solicita cargar nuevamente el archivo propuesto y reemplazar los valores NaN de la columna: reviews_per_month por 0.

# %%
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv")

# %%
archivo["reviews_per_month"]= archivo["reviews_per_month"].fillna(0)
print(archivo)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
print(archivo.count())
# Out:
# id                                48895
# name                              48879
# host_id                           48895
# host_name                         48874
# neighbourhood_group               48895
# neighbourhood                     48895
# latitude                          48895
# longitude                         48895
# room_type                         48895
# price                             48895
# minimum_nights                    48895
# number_of_reviews                 48895
# last_review                       38843
# reviews_per_month                 48895
# calculated_host_listings_count    48895
# availability_365                  48895
# dtype: int64

# %% [markdown]
# 8. Se solicita eliminar las columnas: 'id', 'host_name', 'last_review' del dataset.

# %%
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv")
archivo = archivo.drop(columns=['id', 'host_name', 'last_review'])

# %%
print(archivo.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48879 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   neighbourhood_group             48895 non-null  object
#  3   neighbourhood                   48895 non-null  object
#  4   latitude                        48895 non-null  float64
#  5   longitude                       48895 non-null  float64
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  reviews_per_month               38843 non-null  float64
#  11  calculated_host_listings_count  48895 non-null  int64
# ...

# %% [markdown]
# 9. Realizar un analisis de outliers, con su correspondiente interpretacion asociada.

# %%
archivo.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       38843.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# ...

# %%
archivo.describe().round()
# Out:
#            host_id  latitude  longitude    price  minimum_nights  \
# count      48895.0   48895.0    48895.0  48895.0         48895.0
# mean    67620011.0      41.0      -74.0    153.0             7.0
# std     78610967.0       0.0        0.0    240.0            21.0
# min         2438.0      40.0      -74.0      0.0             1.0
# 25%      7822033.0      41.0      -74.0     69.0             1.0
# 50%     30793816.0      41.0      -74.0    106.0             3.0
# 75%    107434423.0      41.0      -74.0    175.0             5.0
# max    274321313.0      41.0      -74.0  10000.0          1250.0
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count            48895.0            38843.0                         48895.0
# mean                23.0                1.0                             7.0
# std                 45.0                2.0                            33.0
# ...

# %%
import folium 
import pandas as pd
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv", sep=",")
import folium
import pandas as pd
mapa = folium.Map(location=[40.7128, -74.0060], zoom_start=11)
for index, row in archivo.head(100).iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']], popup=row['name']).add_to(mapa)
mapa.save('mapa_airbnb.html')

# %% [markdown]
# A través del siguiente enlace se puede visualizar en mapa todos los hoteles que aparecen en el DataFrame (creo que el enlace solo funciona para mi, quería subirlo a Github para compartirlo pero no me deja crear cuenta): http://localhost:8888/files/Data%20Governance/Actividad%203/mapa_airbnb.html?_xsrf=2%7Cf53b8707%7Cda7dd716915daf56fd76f11cd818c62b%7C1731525735

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv", sep=",")
plt.figure(figsize=(15, 10))

# Scatter plot de 'price' vs 'minimum_nights'
plt.subplot(2, 3, 1)
sns.scatterplot(x=archivo['minimum_nights'], y=archivo['price'])
plt.title('Price vs Minimum Nights')
plt.xlabel('Minimum Nights')
plt.ylabel('Price')

# Scatter plot de 'price' vs 'number_of_reviews'
plt.subplot(2, 3, 2)
sns.scatterplot(x=archivo['number_of_reviews'], y=archivo['price'])
plt.title('Price vs Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Price')

# Scatter plot de 'price' vs 'reviews_per_month'
plt.subplot(2, 3, 3)
sns.scatterplot(x=archivo['reviews_per_month'], y=archivo['price'])
plt.title('Price vs Reviews per Month')
plt.xlabel('Reviews per Month')
plt.ylabel('Price')

# Scatter plot de 'price' vs 'availability_365'
plt.subplot(2, 3, 4)
sns.scatterplot(x=archivo['availability_365'], y=archivo['price'])
plt.title('Price vs Availability (365 days)')
plt.xlabel('Availability (365 days)')
plt.ylabel('Price')

#para visualizar la distribución geográfica)
plt.subplot(2, 3, 5)
sns.scatterplot(x=archivo['longitude'], y=archivo['latitude'])
plt.title('Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Price vs Minimum Nights:** La mayoría de los alojamientos requieren una estancia mínima corta, pero algunos con estancias mínimas largas tienden a tener precios más altos.
#
# **Price vs Number of Reviews:** Las propiedades con precios moderados tienden a recibir más reviews. Las propiedades de lujo (con precios altos) probablemente sean menos comunes y, por lo tanto, tienen menos reviews.
#
# **Price vs Reviews per Month:** Los alojamientos con precios moderados tienen una tasa más alta de reviews mensuales. Los precios muy altos, de nuevo, muestran menos actividad mensual.
#
# **Price vs Availability (365 days)**: Los alojamientos con precios moderados muestran mayor disponibilidad. Las propiedades con precios extremos (muy altos) tienden a tener menor disponibilidad, posiblemente debido a menos reservas.
#
# **Latitude vs Longitude:** Este gráfico muestra la concentración de propiedades en diferentes barrios.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

archivo = pd.read_csv("https://raw.githubusercontent.com/bintutr/Data-Governance-and-Data-Quality-/refs/heads/main/AB_NYC_2019.csv", sep=",")
columnas_relevantes = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']
plt.figure(figsize=(15, 10))
for i, col in enumerate(columnas_relevantes, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=archivo[col])
    plt.title(f'Boxplot de {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Boxplot de price:** La mayoría de los precios están concentrados en el rango más bajo, pero hay algunos valores atípicos que llegan hasta los 10,000.
#
# **Boxplot de minimum_nights:** La mayoría de las estancias mínimas están concentradas en el rango bajo, pero hay algunos valores atípicos que llegan hasta 1,200 noches.
#
# **Boxplot de number_of_reviews:** La mayoría de las propiedades tienen pocas reseñas, con algunos outliers que llegan hasta 600 reseñas.
#
# **Boxplot de reviews_per_month:** La mayoría de las propiedades tienen pocas reseñas por mes, con algunos outliers que llegan hasta 60 reseñas por mes.
#
# **Boxplot de availability_365:** La disponibilidad varía ampliamente, con un rango que va desde 0 hasta 365 días.
